# %%
import pandas as pd

# Load the dataset
data_path = 'data/Raw_Comps_data.csv'
df = pd.read_csv(data_path)

# Display the first few rows of the dataset to understand its structure
df.head()
# Out:
#       Property ID                                              TITLE  \
# 0  vrbo_4049845ha  Greenbrier Estate:Luxury, Theaters & Mesmerizi...
# 1  vrbo_4049845ha  Greenbrier Estate:Luxury, Theaters & Mesmerizi...
# 2  vrbo_4049845ha  Greenbrier Estate:Luxury, Theaters & Mesmerizi...
# 3  vrbo_4049845ha  Greenbrier Estate:Luxury, Theaters & Mesmerizi...
# 4  vrbo_4049845ha  Greenbrier Estate:Luxury, Theaters & Mesmerizi...
#
#   Property Manager/ Host ID  BEDROOMS  ACCOMMODATES     Measure Names  \
# 0    The Cabin Rental Store      28.0          88.0   Property Rating
# 1    The Cabin Rental Store      28.0          88.0  Property Reviews
# 2    The Cabin Rental Store      28.0          88.0      Cleaning Fee
# 3    The Cabin Rental Store      28.0          88.0         Occupancy
# 4    The Cabin Rental Store      28.0          88.0               ADR
#
#    MINIMUM_STAY Airbnb Host URL Airbnb Listing URL  BATHROOMS  ... HAS_POOL  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23480 entries, 0 to 23479
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Property ID                23480 non-null  object
#  1   TITLE                      23480 non-null  object
#  2   Property Manager/ Host ID  23480 non-null  object
#  3   BEDROOMS                   23472 non-null  float64
#  4   ACCOMMODATES               23408 non-null  float64
#  5   Measure Names              23480 non-null  object
#  6   MINIMUM_STAY               22112 non-null  float64
#  7   Airbnb Host URL            14688 non-null  object
#  8   Airbnb Listing URL         14688 non-null  object
#  9   BATHROOMS                  23472 non-null  float64
#  10  CITY_NAME                  23480 non-null  object
#  11  HAS_AIRCON                 23480 non-null  bool
#  12  HAS_GYM                    23480 non-null  bool
# ...

# %%
len(df['Property ID'].unique())
# Out:
# 2935
